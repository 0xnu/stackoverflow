# %%
import csv
from collections import defaultdict, Counter

# %%
with open('data/survey_results_public.csv') as f:
    csv_reader = csv.DictReader(f)
    
    dev_type_info = {}

    for line in csv_reader:
        dev_types = line['DevType'].split(';')

        for dev_type in dev_types:
            dev_type_info.setdefault(dev_type, {
                'total': 0,
                'language_counter': Counter()
            })

            languages = line['LanguageWorkedWith'].split(';')
            dev_type_info[dev_type]['language_counter'].update(languages)
            dev_type_info[dev_type]['total'] += 1

# %%
for dev_type, info in dev_type_info.items():
    print(dev_type)

    #print(language_counter.most_common(5))

    for language, value in info['language_counter'].most_common(5):
        language_pct = (value / info['total']) * 100
        language_pct = round(language_pct, 2)
        
        print(f'\t{language}: {language_pct}%')
# Out:
# Developer, desktop or enterprise applications
# 	JavaScript: 71.08%
# 	SQL: 66.17%
# 	HTML/CSS: 65.09%
# 	C#: 57.18%
# 	Java: 40.71%
# Developer, full-stack
# 	JavaScript: 87.17%
# 	HTML/CSS: 77.83%
# 	SQL: 65.72%
# 	C#: 40.12%
# 	TypeScript: 39.66%
# Developer, mobile
# 	JavaScript: 69.69%
# 	HTML/CSS: 61.64%
# 	Java: 52.7%
# 	SQL: 51.52%
# 	C#: 33.52%
# NA
# 	HTML/CSS: 61.33%
# 	Python: 57.55%
# 	JavaScript: 55.55%
# 	Java: 47.84%
# 	SQL: 41.76%
# Designer
# 	JavaScript: 79.98%
# 	HTML/CSS: 78.58%
# 	SQL: 61.46%
# 	PHP: 39.54%
# 	C#: 39.44%
# Developer, front-end
# 	JavaScript: 88.52%
# 	HTML/CSS: 81.71%
# 	SQL: 59.82%
# 	TypeScript: 41.61%
# 	C#: 37.54%
# Developer, back-end
# 	JavaScript: 75.5%
# 	HTML/CSS: 65.73%
# 	SQL: 65.29%
# 	Java: 41.17%
# 	Python: 40.67%
# Developer, QA or test
# 	JavaScript: 79.07%
# 	HTML/CSS: 71.63%
# 	SQL: 66.01%
# 	Java: 44.38%
# 	Python: 42.84%
# DevOps specialist
# 	JavaScript: 75.34%
# 	SQL: 65.49%
# 	HTML/CSS: 65.4%
# 	Bash/Shell/PowerShell: 60.98%
# 	Python: 51.22%
# Developer, game or graphics
# 	JavaScript: 74.1%
# 	HTML/CSS: 67.47%
# 	C#: 57.23%
# 	SQL: 53.41%
# 	C++: 45.78%
# Database administrator
# 	SQL: 83.93%
# 	JavaScript: 77.41%
# 	HTML/CSS: 76.58%
# 	Bash/Shell/PowerShell: 46.92%
# 	C#: 45.18%
# Developer, embedded applications or devices
# 	JavaScript: 64.33%
# 	HTML/CSS: 58.63%
# 	SQL: 53.7%
# 	Python: 53.7%
# 	C++: 50.19%
# Engineer, data
# 	SQL: 71.95%
# 	Python: 67.25%
# 	JavaScript: 62.85%
# 	HTML/CSS: 59.03%
# 	Bash/Shell/PowerShell: 46.11%
# Educator
# 	JavaScript: 74.21%
# 	HTML/CSS: 70.08%
# 	SQL: 59.25%
# 	Java: 41.93%
# 	Python: 40.55%
# System administrator
# 	JavaScript: 76.45%
# 	HTML/CSS: 72.51%
# 	SQL: 72.07%
# 	Bash/Shell/PowerShell: 56.74%
# 	Python: 53.01%
# Engineering manager
# 	JavaScript: 75.05%
# 	HTML/CSS: 62.67%
# 	SQL: 61.68%
# 	Python: 48.1%
# 	Bash/Shell/PowerShell: 43.31%
# Product manager
# 	JavaScript: 77.64%
# 	HTML/CSS: 72.88%
# 	SQL: 60.46%
# 	Python: 45.34%
# 	Java: 40.37%
# Data or business analyst
# 	SQL: 78.63%
# 	HTML/CSS: 63.13%
# 	JavaScript: 60.06%
# 	Python: 60.06%
# 	Bash/Shell/PowerShell: 37.71%
# Academic researcher
# 	JavaScript: 62.11%
# 	Python: 60.18%
# 	HTML/CSS: 57.02%
# 	SQL: 48.95%
# 	Java: 42.46%
# Data scientist or machine learning specialist
# 	Python: 82.01%
# 	SQL: 65.19%
# 	HTML/CSS: 53.54%
# 	JavaScript: 52.95%
# 	Bash/Shell/PowerShell: 43.66%
# Scientist
# 	Python: 73.76%
# 	JavaScript: 56.08%
# 	HTML/CSS: 51.1%
# 	Bash/Shell/PowerShell: 45.86%
# 	SQL: 45.86%
# Senior executive/VP
# 	JavaScript: 77.08%
# 	HTML/CSS: 71.94%
# 	SQL: 63.24%
# 	Python: 45.45%
# 	Bash/Shell/PowerShell: 40.71%
# Engineer, site reliability
# 	JavaScript: 73.12%
# 	SQL: 62.9%
# 	Bash/Shell/PowerShell: 62.1%
# 	HTML/CSS: 60.22%
# 	Python: 58.6%
# Marketing or sales professional
# 	HTML/CSS: 76.29%
# 	JavaScript: 75.26%
# 	SQL: 58.76%
# 	PHP: 43.3%
# 	Python: 34.02%
